# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib
matplotlib.use('TkAgg')
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
xlen = len(X)
Y = np.arange(-5, 5, 0.25)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

colortuple = ('y', 'b')
colors = np.empty(X.shape, dtype=str)
for y in range(ylen):
    for x in range(xlen):
        colors[x, y] = colortuple[(x + y) % len(colortuple)]

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=colors,
        linewidth=0, antialiased=False)

ax.set_zlim3d(-1, 1)
ax.w_zaxis.set_major_locator(LinearLocator(6))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-58b4a6f789c2> in <module>()
#      29 ax.w_zaxis.set_major_locator(LinearLocator(6))
#      30
# ---> 31 plt.show()
#
# /anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py in __call__(self, block)
#     191
#     192         if not is_interactive() or get_backend() == 'WebAgg':
# --> 193             self.mainloop()
#     194
#     195     def mainloop(self):
#
# /anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_tkagg.py in mainloop(self)
#      69 class Show(ShowBase):
#      70     def mainloop(self):
# ---> 71         Tk.mainloop()
#      72
#      73 show = Show()
#
# ...

# %%
from pygraphviz import *


Node_Names = ['new idea', 'old idea', 'did you prove there was an old idea?', 'did you respect the journal?', 'did you teach something new and unexpected?',\
 'is there real life drama?', 'does it have mathematics? (easy math)', 'does it have striking graphs?']


#== Graph 1

G = AGraph (strict='false', directed = 'true', landscape='false',ranksep='2.5', splines = 'true', overlap='scalexy', nodesep='2.6', elenght=1.0, eweight=0.5)


G.add_node(Node_Names[0])



filename = 'Publishing1' 
program = 'neato'
G.layout(program, args='-Gepsilon=0.000001; overlap="false"')
file_name = program+"_"+filename
G.write(file_name+"_output.xdot")
G.draw(file_name+".svg")



#== Graph 2


G = AGraph (strict='false', directed = 'true', landscape='false',ranksep='2.5', splines = 'true', overlap='scalexy', nodesep='2.6', elength=3.0, eweight=2.5)


G.add_node(Node_Names[0])
G.add_node(Node_Names[1])

G.add_edge (Node_Names[1], Node_Names[0], length = '5.0')


filename = 'Publishing2' 
program = 'neato'
G.layout(program, args='-Gepsilon=0.000001; overlap="false"')
file_name = program+"_"+filename
G.write(file_name+"_output.xdot")
G.draw(file_name+".svg")



#== Graph 3


G = AGraph (strict='false', directed = 'true', landscape='false',ranksep='2.5', splines = 'true', overlap='scalexy', nodesep='2.6', elength=3.0, eweight=2.5)


G.add_node(Node_Names[0])
G.add_node(Node_Names[1])

G.add_edge (Node_Names[1], Node_Names[0], length = '5.0')

Cluster_Paper = G.subgraph(nbunch=[0,1],
                name="cluster1",
                color='black',
                label='cluster 1 label')



G.add_edge (Node_Names[2], Cluster_Paper, length = '5.0')






filename = 'Publishing3' 
program = 'fdp'
G.layout(program, args='-Gepsilon=0.000001; overlap="false"')
file_name = program+"_"+filename
G.write(file_name+"_output.xdot")
G.draw(file_name+".svg")














'''
G = AGraph (strict='false', directed = 'true', landscape='false',ranksep='2.5', splines = 'true', overlap='scalexy', nodesep='0.6', elenght=1.0, eweight=0.5)

for node in Node_Names:
    G.add_node(node)



filename = 'Publishing2' 
program = 'neato'
G.layout(program, args='-Gepsilon=0.000001; overlap="false"')
file_name = program+"_"+filename
G.write(file_name+"_output.xdot")
G.draw(file_name+".svg")

'''

# %%
from pygraphviz import *

G = AGraph (strict='false', label = '', fontsize = '40', directed = 'false', landscape='false',ranksep='1.5', splines = 'true', overlap='scalexy',  sep="+5,5") #, sep="+25,25" nodesep='0.5',
G.edge_attr['style']='solid' 
G.graph_attr['fontname']='Helvetica' 
G.graph_attr['fontsize']=32
G.graph_attr['fontcolor']='red'

NumHardLocations = 100

for r in range (NumHardLocations):
	G.add_node(r, shape= 'circle'  , color= 'black', fontname= 'Helvetica', label = '', height='1.0')
	print ('Creating graph node ', r)

program = 'neato'
G.layout(program, args='-Gepsilon=0.01; overlap="true"')
file_name = 'KanervaRead_0'
G.write(file_name+"_output.dot")
G.draw(file_name+".svg")


# Fix the node positions
for r in G.nodes():
	r.attr['pos']=r.attr['pos']+"!" 


#insert new node
G.add_node(NumHardLocations, label = '/&beta', shape= 'none'  , color= 'red', style = 'solid', fontname= 'Helvetica', height='1.0')
print ('inserting virtual location!')

for r in range (NumHardLocations):
	G.add_edge(r, NumHardLocations) 
	print ('Linking... ')

program = 'neato'
G.layout(program, args='-Gepsilon=0.01; overlap="true"')
file_name = 'KanervaRead_1'
G.write(file_name+"_output.dot")
G.draw(file_name+".svg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2f44def3e5d9> in <module>()
# ----> 1 from pygraphviz import *
#       2
#       3 G = AGraph (strict='false', label = '', fontsize = '40', directed = 'false', landscape='false',ranksep='1.5', splines = 'true', overlap='scalexy',  sep="+5,5") #, sep="+25,25" nodesep='0.5',
#       4 G.edge_attr['style']='solid'
#       5 G.graph_attr['fontname']='Helvetica'
#
# ModuleNotFoundError: No module named 'pygraphviz'
